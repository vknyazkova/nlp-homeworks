# %% [markdown]
# ## Парсинг сайта irecommend

# %%
from bs4 import BeautifulSoup
import requests
import time
import random

# %%
from fake_useragent import UserAgent

# %%
ua = UserAgent(verify_ssl=False)
headers = {'User-Agent': ua.random}
print(headers)
# Out:
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36'}

# %%
session = requests.session()

# %%
response = session.get(f'https://irecommend.ru/catalog/reviews/877-897')
response
# Out:
# <Response [200]>

# %%
def get_raiting(review):
    div_star = review.find_all('div', class_='star')
    raiting = 0
    for star in div_star: 
        if star.find('div')['class'][0] == 'on':
            raiting += 1
    return raiting

# %% [markdown]
# Собираем ссылки на полный отзыв, пока не наберем каждого типа отзывов по 40 штук. Позитивными я буду считать отзыв с 5 и 4 звездочками, остальные будут негативными. Так как сайт неохотно отдает данные, я подумала, что после 521 ошибки смена user-agent'a и более долгая пауза помогут. Не знаю, правда, помогло это в итоге или нет)

# %%
reviewlinks = {'positive': [], 'negative': []}
for page in range(40, 100):
    response = session.get(f'https://irecommend.ru/catalog/reviews/877-897?page={page}', headers=headers)
    print(response)
    if response.status_code == 200:
        page_content = BeautifulSoup(response.text)
        review_teasers = page_content.find_all('div', class_='teaser-item')
        for teaser in review_teasers:
            raiting = get_raiting(teaser)
            if raiting < 4:
                label = 'negative'
            else:
                label = 'positive'
            reviewlinks[label].append(teaser.find('div', class_='reviewTextSnippet').find('a', href=True)['href'])
        if (len(reviewlinks['positive']) >= 40) and (len(reviewlinks['negative']) >= 40):
            break
    else:
        time.sleep(random.uniform(30.1, 35.2))
        headers = {'User-Agent': ua.random}
    time.sleep(random.uniform(10.1, 15.2))
reviewlinks

# %% [markdown]
# Сохраню ссылки в файл, чтобы больше не перезапускать эту ячейку.

# %%
import json

# %%
with open('links.json', 'w') as f:
    json.dump(reviewlinks, f)

# %%
with open('links.json', 'r') as f:
    reviewlinks = json.load(f)

# %%
len(reviewlinks['negative']), len(reviewlinks['positive'])
# Out:
# (40, 220)

# %%
positive = random.choices(reviewlinks['positive'], k=len(reviewlinks['negative'])) 
negative = reviewlinks['negative']

# %% [markdown]
# Я сначала брала текст, находящийся внутри тегов \<p>, потому что на нескольких страничках так и было, но потом заметила, что в некоторых отзывах, не хватает части текстов. Посмотрев эти отызвы я поняла, что на этом сайте текст может быть не только внутри тегов \<p> но и где-то просто внутри \<div>. В итоге пришлось брать текст просто с помощью .text из всего div'а, но так туда попадал и текст из ссылок, то пришлось найти все ссылки и удалить их из всего текста...

# %%
def get_full_review(review_text):
    soup = BeautifulSoup(review_text)
    review = soup.find('div', class_='reviewText')
    reviewtext = review.text
    
    ahref = review.find_all('a', href=True)
    href_text = [a.text for a in ahref]
    for t in href_text:
        reviewtext = reviewtext.replace(t, '')
        
    reviewtext = reviewtext.replace('\n', '')
    return reviewtext

# %% [markdown]
# А еще с этим сайтом какая-то беда, он чуть что выкидывает ошибку 521(( Никакие ожидания и смены user-agent'a не помогают( Поэтому решила сделать рекурсирвную функцию, которая будет запрашивать пока сайт не вернет нормальный ответ

# %%
def get_review(link):
    headers = {'User-Agent': ua.random}
    response = session.get(f'https://irecommend.ru{link}', headers=headers)
    print(link, response)
    if response.status_code == 200:
        return get_full_review(response.text)
    else:
        headers = {'User-Agent': ua.random}
        time.sleep(random.uniform(25.1, 37.2))
        return get_review(link)

# %%
positive_reviews = []

# %%
for link in positive:
    positive_reviews.append(get_review(link))
    time.sleep(random.uniform(5.1, 7.2))
positive_reviews

# %%
len(positive_reviews)
# Out:
# 40

# %% [markdown]
# На всякий случай запишу в файл, чтобы больше не парсить сайт, потому что сайт очень плохо отдает данные((((

# %%
with open('positive.txt', 'w', encoding='utf-8') as newf:
    newf.write('\n'.join(positive_reviews))

# %%
negative_reviews = []

# %%
for link in negative:
    negative_reviews.append(get_review(link))
    time.sleep(random.uniform(3.1, 5.2))
negative_reviews
# Out:
# /content/ochen-plokhoi-krem-vykinula-tselyi-tyubik <Response [521]>
# /content/ochen-plokhoi-krem-vykinula-tselyi-tyubik <Response [200]>
# /content/uzhas-da-i-tolko-istoriya-o-tom-kak-etot-krem-isportil-kozhu <Response [200]>
# /content/moe-litso-ne-obradoval <Response [200]>
# /content/ne-vsegda-stoit-prislushivatsya-s-predstavitelyam-brenda-v-magazine-i-vot-pochemu <Response [200]>
# /content/rezultata-net-ya-ego-zhdala <Response [521]>
# /content/rezultata-net-ya-ego-zhdala <Response [200]>
# /content/eto-kak-krem-za-4-kosarya-ya-khochu-chtoby-normalno-rabotal-ot-i-do-bez-kakikh-lishnikh-mani <Response [521]>
# /content/eto-kak-krem-za-4-kosarya-ya-khochu-chtoby-normalno-rabotal-ot-i-do-bez-kakikh-lishnikh-mani <Response [521]>
# /content/eto-kak-krem-za-4-kosarya-ya-khochu-chtoby-normalno-rabotal-ot-i-do-bez-kakikh-lishnikh-mani <Response [200]>
# /content/khoroshii-no-zabitye-pory-vse-isportili <Response [200]>
# /content/krem-troechnik-no-s-zamashkoi-na-otlichnika-chto-zhe-predstavlyaet-iz-sebya-gialuronovyi-fil <Response [521]>
# /content/krem-troechnik-no-s-zamashkoi-na-otlichnika-chto-zhe-predstavlyaet-iz-sebya-gialuronovyi-fil <Response [200]>
# /content/popalsya-v-byuti-bokse <Response [521]>
# /content/popalsya-v-byuti-bokse <Response [521]>
# /content/popalsya-v-byuti-bokse <Response [200]>
# /content/sobstvenno-nichego-dramatichnogo <Response [521]>
# /content/sobstvenno-nichego-dramatichnogo <Response [521]>
# /content/sobstvenno-nichego-dramatichnogo <Response [200]>
# /content/krem-khorosho-uvlazhnyaet-no-ochen-lipkii-prikhoditsya-potom-smyvat-zapakh-strannyi-kak-budt <Response [200]>
# /content/neodnoznachnye-vpechatleniya-kak-rabotaet-na-zhirnoi-kozhe-35 <Response [521]>
# /content/neodnoznachnye-vpechatleniya-kak-rabotaet-na-zhirnoi-kozhe-35 <Response [200]>
# /content/dlya-chuvstvitelnoi-kozhi-ne-dlya-zhirnoi <Response [521]>
# /content/dlya-chuvstvitelnoi-kozhi-ne-dlya-zhirnoi <Response [521]>
# /content/dlya-chuvstvitelnoi-kozhi-ne-dlya-zhirnoi <Response [200]>
# ['Всем солнечного настроения!Одним солнечным тёплым утром...  Попробовала данный крем для лица. А потом и тёплым солнечным вечером тоже. И так несколько дней.  Ароматы... ароматы лаванды... Такие ненавязчивые и приятные.Мои впечатления от использования.Крем и правда питательный. Для меня он оказался на грани того, чтобы быть сколько-нибудь тяжеловатым, хотя ведь не жирный, распределяется хорошо и впитывается также. Ощущение липкости, как иногда бывает у питательных кремов, присутствует, но совсем не критичное, а даже еле-еле заметное. Декоративная косметика, включая праймеры, на данный крем "ложится" без проблем. Понравилась консистенция. Расход вполне себе экономичный. Какого-то эффекта кроме устойчивого увлажнения, мягкости и бархатистости не заметила. Один только этот крем мне ничего не разглаживает, более эластичной кожу не делает Крышечка исправна. Удобно пользоваться.Этим питательным кремом пользовалась как отдельно, так и совместно с другими продуктами от Крымской розы:Так, вся "коллекция" серии Lavender скоро соберется Заказан продукт на Озоне.Крем точно хорош. Для моей кожи, конечно, есть более подходящие претенденты. Однако, данный питательный крем достойный продукт, которым пользоваться очень даже приятно.   \u200b\u200b\u200b\u200b\u200b\u200b          ',
#  'Год назад недолго думая и читая отзывы спонтанно приобрела данный крем на озон, тогда он стоил дешевле и поэтому было бы не обидно, если бы он оказался не удачным.Пришел крем в стеклянной баночке, что меня очень удивило.  Состав: Консистенция гелево-кремовая, приятная, не тяжелая. Запах в целом нейтральный, но есть легкие нотки неприятной химии, такие немного бензиновые что ли, но в целом ничего критичного и навязчивого.  Моя кожа сухая и тонкая 25+, имеются мимические морщинки, никаких особых проблем, но чувствительная. Для глубокого ухода я предпочитаю использовать более насыщенные крема на ночь, а с утра наносить что-то полегче. Поэтому мне показалось что крем идеально подойдет мне на день. Весной и летом увлажнения было достаточно, никаких раздражений, шелушений, аллергии, прыщей он не вызвал. Осенью и зимой уже оказался слабоват даже как просто увлажняющий. И вроде как ничего откровенно негативного о нем сказать не могу, но с другой стороны, использовав кучу не дорогого корейского ухода, не могу сказать что он на первых местах. Бывало крем за небольшие деньги делал кожу мягче, более сияющей, выравнивал тон или больше питал, а тут он просто убирает шелушения, ничего более, а иногда мне даже казалось что кожа становится сероватой.Процесс распределения по коже:     Мнение моего мужа с комби кожей оказалось более позитивным, ему крем пришелся по душе, даже в более холодные сезоны. Понравился он ему как раз потому, что ему только и нужно убирать шелушения с щек, а в остальном он не привередлив. По финишу этот крем какой-то полуматовый, что тоже оказалось кстати. Муж как раз и помог мне полностью добить этот крем.\xa0Вывод: Если вам просто нужно убрать стянутость с лица, поверхностно увлажнить шелушения, вы любите не сильно влажный финиш, то этот крем вам подойдет. А вот если кожа возрастная или сухая, то не советую, лучше взять крем даже в какой-нибудь Подружке на скидках.\xa0Взяла бы я его сейчас за 580? Нет.Планирую ли приобретать его в будущем? Тоже нет.Значит ли это, что крем плохой? Не сказала бы: крем неплохой, просто далеко не лучший за эту цену.  ',
#  'Не так давно в ближайшей Подружке была распродажа 70% и я решила купить себе что-то матирующее на жару. Eveline Beauty & glow keep balanceПонравился дизайн упаковки и я люблю кремы в тюбиках. И к марке Eveline я в который раз ищу подход. Тем более многие отмечают улучшение качества и рабочие формулы.Упаковка на мой вкус безупречная, очень приятно держать в руках. отлично сделали. Eveline Beauty & glow keep balanceТекстураТекстура оказалась плотнее, чем я думала. Наносится как густой крем. Eveline Beauty & glow keep balanceАроматОтдушка не сильная, но есть, не могу сказать, что понравилась, но за счет своей легкости не мешает и не напрягает. Eveline Beauty & glow keep balanceЭффектВпитывается не мгновенно. Я наношу, потом расчесываюсь, укладываю брови, а потом уже крашусь.С тональными средствами не конфликтует. На лице ощущается первое время, потом нет.Он не скатывается, я проверила как следует, терла и на руке, нормальный крем. Eveline Beauty & glow keep balanceИ воде бы всё ок, но нет. Он не выполняет свои обещания, а именно не матирует. Он вообще не матирует кожу, как так, это же матирующий крем.Далее, после нанесения на коже появляются какие-то капельки воды. Если успеть нанести макияж, то они появляются поверх него. А если нанести чуть позе, то приходится промакивать салфеткой капельки.Первые дни я думала, что это мой пот из-за жары, но жара спала, а капельки появлялись. Плюс без крема лицо не потело вообще.То есть матирующий крем с блестящими капельками))Ждала накопительного балансирующего эффекта, тоже не дождалась.Из плюсов.Он хорошо смягчает увлажняет кожу. Но а этом всё.Хотелось чего-то легкого и матирующего на лето, не получилось)Я продолжаю им пользоваться для смягчения кожи.Как матирующий крем рекомендовать не могу.Спасибо, что читаете, хорошего дня и удачных покупок.Здесь мои отзывы на  и на  И про мой .  ',
#  'Приветствую всех, кто читает этот отзыв! 🙋\u200d♀️〰️〰️〰️〰️〰️〰️〰️〰️〰️〰️〰️〰️〰️〰️〰️〰️〰️〰️〰️〰️\xa0Приобрела я сразу два средства марки TIAM, 🤍 гель-крем для лица, без масла AC Fighting Oil-Free Aqua Cream, и🤍 точечный крем против воспалений AC Fighting Spot Rx Cream. Очень хотела попробовать точечное средство от воспалений. Так много наслышенная о нем от блогеров... а тут ещё и появились высыпания на кожи, и захотелось протестировать на себе. Найти данное средство оказалось не просто, нигде я не смогла его найти, (это было где-то пол года назад) сейчас к слову, оно доступно и на озон и wb. Свой заказ я сделала в корейском интернет магазине и добрав до бесплатной доставки я решила в комплект приобрести крем из этой же серии, гель-крем для лица, без масла, AC Fighting Oil-Free Aqua Cream. Этот отзыв будет о нем,🤍 гель-креме для лица, без масла, AC Fighting Oil-Free Aqua Cream.Цена: от 1800/2200р. в зависимости от скидкиОбъём: 80 млПроизводство: Южная КореяГде купить: Фирменные магазины Корейской косметики, Озон, Wildberries〰️〰️〰️〰️〰️〰️〰️〰️〰️〰️〰️〰️〰️〰️〰️〰️〰️〰️〰️〰️\xa0Начну с внешнего вида...\xa0🤍 ОФОРМЛЕНИЕ 🤍Данная серия оформлена в сочетании двух цветов, белый и красный ❤️ 🤍 Крем находился в картонной упаковке, без дополнительной пленки, нет никаких следов и способов защиты от вскрытия, вплоть до самого крема... я такое не люблю...Дизайн ❤️🤍 на белом фоне красно-чёрный шрифт с названием крема, обрамлено по периметру красной рамкой. Просто и стильно.Сверху и снизу коробка ярко красная.  По бокам, информация на языке производителя.На моем экземпляре нет никаких наклеек с переводом на русский язык.  Далее идёт сам крем в пластиковой банке с завинчивающейся крышкой. Пластик матовый и полупрозрачный. Под крышкой ещё одна крышка с ушком... На дне тары, сроки годности.И что обидно, мне достался крем с некачественно наклейной этикеткой на банке, от этого внешний вид и впечатления в целом немного омрачаются... Больше всего, конечно, нравится когда напечатано непосредственно все на самой банке, нежили этикетки, да ещё и не идеальные, а криво с пузырями приклеено.Убеждена, что это не подделка, тк второй крем в идеальном состоянии и данному магазину я доверяю, не первый раз их клиент, но вот попалось такое...\xa0🤍 ТЕКСТУРА 🤍 Гель-крем очень необычной консистенции, слово крем вообще не подходит под описание. Густая гелеобразная субстанция и никакого сходства с кремом... В банке гель-крем нежно розового оттенка, на коже, кажется, абсолютно прозрачным... При нанесении крем не течёт, текстура упругая и густая, не вязкая. Ложится и распределяется по коже легко, немного подтаивает на ней и становится жиже и податливее. Усаживается и впитывается достаточно быстро. Финиш крема, абсолютно матовый. Сам производитель описывает гель-крем так:Лёгкая невесомая консистенция быстро впитывается в кожу и даёт пролонгированное увлажнение, защищая от испарения влаги. 🤍 СОСТАВ 🤍\xa0Хочется сразу подметить в этом пункте, Главный козырь этого крема-геля, что он без масла в составе. Это полный состав от производителя:Water, Glycerin, Bifida Ferment lysate, Dipropylene glycol, Niacinamide, Sodium Hyaluronate, PEG/PPG-17/6 copolymer, Galactomyces ferment filtrate, Saccharomyces/Nelumbo Nucifera Ferment Extract Filtrate, Nelumbo Nucifera Flower Extract, Prunus Mume Fruit Extract, Lactobacillus, Pseudoalteromonas Ferment Extract, Lactobacillus/Eriodictyon Californicum Ferment Extract, Saccharomyces Ferment Filtrate, Helianthus Annuus Seed Oil, LUpinus Albus Seed Extract, Betaine, Opuntia Ficus-indica Stem Extract, Hydrolyzed Lepidium Meyenii Root, Nelumbo Nucifera Root Extract, Ceramide NP, Camellia Sinensis Leaf Extract, Oryza Sativa Extract, Taraxacum officinale, Snail Secretion Filtrate, Bamboo Vinegar, Glycine Soja Seed Extract, Sesamum Indicum Seed Extract, Biosaccharide Gum-1, Citrus Grandis Peel Oil, Lemon Fruit Oil, Citrus Aurantium Dulcis (Orange) Oil, PEG-60 Hydrogenated Castor Oil, Carbomer, Tromethamine, Phenyl TrimethicOne, Glyceryl polyacrylate, Adenosine, ...
#  'Здравствуйте! Сегодня речь пойдет о нашумевшей сыворотке на основе ретиналя от производителя Medik8. Крем-сыворотка Medik8 Crystal Retinal - это серия средств представлена в четырёх версий , и номер сыворотки (1-3-6-10) возрастает от процентного содержания ретинала в составе . Заметьте именно РЕТИНАЛА, а не ретинола. А в чем разница между ними, я расскажу позже. Так как я новичок в ретиноловом уходе и плюс у меня сухая кожа, я выбрала Crystal Retinal 1 с наименьшим инкапсулированным ретиналем 0.01%. Это самая мягкая и щадящая формула в этой линейке. Что пишет производитель  Табличка «Виды ретиноидов, их свойства для кожи»Линия «Crystal Retinal” использует потенциал ретинальдегида – инновационной молекулы нового поколения, инкапсулированной в кристаллической структуре для максимальной стабильности. Medik8 предлагаем 4 разные концентрации ретинальдегида: 0,01% в Crystal Retinal 1™; 0,03% в Crystal Retinal 3™; 0,06% в Crystal Retinal 6™ и 0,1% в Crystal Retinal 10™. Самая маленькая концентрация предназначена для самой чувствительной кожи.\xa0 ✔️ Почему я решила начать использовать в уходе ретинол и его производные? Я не являюсь поклонником ни агрессивно-кислотного ухода, ни маниакально-ретинолового. Считаю, что кожа -это все-таки орган, и его тоже нужно беречь. Проблемы в виде брыль, морщин, потери овала лица лежат не на поверхности, то есть в коже, а поглубже - в мышцах лица. Но все же с возрастом не помешает помогать своей кожи обновляться, так как после 30 лет обновления эпидермиса кожи очень замедляется. Но только одним ретинолом молод не будешь, нужен и самомассаж лица, и полноценное питание, и физические нагрузки и даже позитивное мышление!Моя кожаМоя кожа нормальная, склонная к сухости, особенно в отопительный сезон. Мне 38 лет. Морщин не наблюдаю, последнее время появляются мелкие заломы под глазами. На лбу имею мимические морщины уже очень много лет, и только самомассаж лица или инъекции ботокса (раз в год или полтора года) мне помогают справляться с ними. Имеется пигментация на лице, которая удачно убирается при помощи лазера, но при первом активном солнце возвращается.Что такое ретинал , его свойства , чем отличается от ретинола , виды ретиноидов в косметике  Ретинол это жирорастворяющий витамин. У ретинола имеются различные формы, и тут нужно быть аккуратным, чтобы не навредить коже, не вызвать ожоги и чрезмерную сухость. Я составила табличку, изучая этот вопрос. По этой табличке легко ориентироваться, и подобрать для себя нужный вид.Витамин А или же ретиноиды – это собирательный термин для всех молекул витамина А и его производных. Ретинол, ретинальдегид, ретиноевая кислота, ретинил пальмитат – все они классифицируются как ретиноиды. Ретиналь имеет мягкое бережное действие. Клинически доказано, что ретиналь действует до 11 раз быстрее, чем ретинол, и обеспечивает мощное антивозрастное действие, стимулирует сияние и борется с высыпаниями. В табличке, которую я составила, указала основные виды ретиноидов в косметике, для чего служат. Например, для новичков и людей с чувствительной кожей лучше начать использовать косметику, где содержится ретинил пальмитат или ретинил ацетат, или же ретинол с очень маленьким процентом содержанием. Также вся косметика с ретиноидами достаточно капризная, нужно аккуратно сочетать с другими косметическими средствами. ✅РЕТИНОИДЫ НЕ СОЧЕТАЮТСЯ:📌AHA-кислоты 📌BHA-кислоты📌солнце, кислород 📌третиноин+бензол пероксид📌адапален +бензоил📌гиалуроновая кислота (под вопросом) ✅Ретиноиды хорошо сочетаются: 📌липиды ( ланолин, силиконы, сквалан, масло ши, глицерин)📌антиоксиданты 📌центелла азиатская📌ликопин📌ретинальдегид+бензоил📌spf Перед тем как начать описание моих ощущений от этой сыворотке, хочу разобрать состав. Очень часто вижу отзывы о косметике, но девушки опускают даже указать состав продукта, хотя это так важно! Многие производители откровенно говоря непорядочные в этом плане, и от состава просто хочется возмущаться. Я все составы разбираю по сайтам, где предоставляют возможность это сделать онл ...
#  'Всем приветик!Закончился крем, поэтому сразу же побежала в летуаль. Были скидки и за приятную цену около 250-300 рублей купила этот наимилейший крем. Аромат очень приятный, и правда отдаёт клубникой. Крем белого цвета. Очень неприятные ощущения после применения. Впитывается слишком быстро, кожа после применения на ощупь словно грязная, жирная и неприятная, сразу же хочется снова умыться.  Но я думала это так и должно быть, но спустя неделю использования на коже стали появляться прыщи, поры забились, появились черные точки, крем фу.  Единственное приятное оформление и аромат, больше ничего.Спасибо’  ',
#  'Приветствую Всех!Отправляясь в магазин за косметикой, на что вы обращаете внимание в первую очередь? Я, например, очень любопытная. Сразу замечаю пополнение ассортимента. А еще не могу пройти мимо банок с симпатичным оформлением. Сегодня хочу рассказать о средстве, которое приобрела как раз по такому принципу. Главный герой отзыва – Крем для лица Белита-Витэкс Омолаживающий комплекс Biodermin PharmaCos 30+.Где купить: Официальный интернет-магазин, Ozon, Wildberries. Я брала в Магнит-Косметик.Стоимость: ≈ 200 руб;Объем: 50 мл. Крем для лица Белита-Витэкс Омолаживающий комплекс Biodermin PharmaCos 30+УПАКОВКАУ средства гармоничное оформление, выполненное в нежных оттенках.Картонная коробочка аккуратная, держит форму. На ней достаточно информации. Текст воспринимается хорошо – есть разграничения и выделения.Туба стандартной формы, на поверхности стоит устойчиво. Она изготовлена из тактильно приятного материала, снабжена винтовой крышкой. Крем для лица Белита-Витэкс Омолаживающий комплекс Biodermin PharmaCos 30+Отверстие для извлечения крема небольшое. Изначально было защищено фольгированной мембраной. Упаковка крема для лица Белита-Витэкс Biodermin PharmaCos 30+ Упаковка крема для лица Белита-Витэкс Biodermin PharmaCos 30+ИНФОРМАЦИЯ ОТ ПРОИЗВОДИТЕЛЯ Состав крема для лица Белита-Витэкс Biodermin PharmaCos 30+Состав: Вода, цетиловый спирт, глицерилстеарат, ПЭГ-75 стеарат, цетет-20, стеарет-20, циклопентасилоксан, циклогексасилоксан, глицерилтрикаприлат/капрат, экстракт водорослей, экстракт Codium fragile (морского винограда), полиметилсилсесквиоксан, диметикон, изогексадекан, цетеарилметикон, ПЭГ-40 стеарат, стеарет-2, стеарет-21, пропилгептилкаприлат, масло Prunus amygdalus dulcis (сладкого миндаля), экстракт плодов Mangifera indica (манго), кроссполимер диметикона, дезамидоколлаген, Mg PCA, феноксиэтанол, метилпарабен, этилпарабен, пропилпарабен, экстракт листьев Ginkgo biloba (гинкго), изопропилмиристат, масло зародышей Triticum vulgare (пшеницы), токоферилацетат, БГТ, парфюмерная композиция, ксантановая камедь, 2-бром-2-нитропропан-1,3-диол, бензилсалицилат, бутилфенилметилпропиональ, цитронеллол, лимонен, гераниол, гексилциннамаль, линалол.В составе много растительных экстрактов, в том числе экстракт гинкго билоба, известный антивозрастными свойствами и мощным антиоксидантным действием.Также обратила внимание на присутствие натуральных масел – сладкого миндаля и зародышей пшеницы. Первое обладает низким уровнем комедогенности, а второе – высоким, оно может стать причиной забитых пор. Это стоит учитывать. Следить за реакцией кожи, особенно проблемной.НАЗНАЧЕНИЕпо типу кожи: для зрелой;по возрасту применения: 30+;по проблеме: против морщин.ХАРАКТЕРИСТИКИ СРЕДСТВАКрем белого цвета. У него нежная консистенция, больше напоминающая лосьон. Запах – косметический, с пудровыми нотами. Консистенция крема для лица Белита-Витэкс Biodermin PharmaCos 30+ВПЕЧАТЛЕНИЯ ОТ ИСПОЛЬЗОВАНИЯОзнакомившись с описанием крема, решила оставить его для вечерней рутины. Но когда дело дошло до использования, все оказалось не так очевидно. Крем легкий, в нем совсем не чувствуется жирности. Он хорошо распределяется, быстро впитывается. Расход выходит небольшой. Впечатления от использования крема для лица Белита-Витэкс Biodermin PharmaCos 30+ Впечатления от использования крема для лица Белита-Витэкс Biodermin PharmaCos 30+Сразу после нанесения кожа выглядит матовой. На ощупь она гладкая и бархатистая. Как будто на ней лежит тонкий слой шелковистой пудры. Увлажнение слабое. Даже для моей, склонной к жирности, кожи его недостаточно. На отдельных зонах ощущается стянутость. Мелкие морщинки в уголках глаз не скрадываются.Такое действие приемлемо разве что для основы под макияж. От омолаживающего крема я ждала другого. Хотела больше питательности и увлажнения.ИТОГ Отзыв о креме для лица Белита-Витэкс Biodermin PharmaCos 30+Крем для лица Белита-Витэкс Омолаживающий комплекс Biodermin PharmaCos 30+ оказался спорным. У него гармоничное оформление, приятный пудровый а ...
#  'Не то, что бы я верю всем этим заверениям, что косметика из каталогов реально может решить какие-либо проблемы. Нет, конечно же, она что-то делает, но все обещания надо делить минимум пополам. А иногда, как с этим кремом, лучше вообще не верить. крем для лица от постакне Dr. Core от Faberlic интенсивно восстанавливает структуру кожного покрова. Средство помогает в кратчайшие сроки избавиться от постакне, а также оно разглаживает поверхность кожи и выравнивает тонПомимо этого крем обладает мощным питательным и увлажняющим действием. Благодаря ему кожа выглядит более здоровой, свежей и молодой. Крем создан специально для бережного ухода за проблемной и жирной кожей лица.Он подходит для любого возраста. Средство улучшает состояние кожного покрова и способствует реконструкции его структуры. При регулярном использовании наблюдается оздоровление кожного покрова, улучшается его цвет, пропадают постакне.\xa0Продукт также подходит для избавления от следов, оставшихся после «маскне» — это акне, появляющиеся после долгого применения респиратора либо маски. Про ценуНа официальном сайте марки есть раздел, где продают косметику с ограниченным сроком годности. По сути я купила пробник за 88 рублей.Но если быть справедливым, вы вполне можете использовать продукт и до конца уже за пределами срока годности, особенно если он визуально не изменился, ничего с вами не случится. Про упаковкуМне очень понравилось оформление серии, выглядит прям как космецевтика. На упаковке есть полная информация о продукте, которая частично дублируется на тубе. На тубе есть очень удобная защита от первого вскрытия на крышке флип-топ. Про консистенцию и ароматКрем белый, лёгкий, я бы даже сказала, что воздушный. Аромат с небольшой медицинской направленностью, не раздражает при использовании.  Aqua, Niacinamide, C15-19 Alkane, Macadamia Ternifolia Seed Oil, Squalane, Cetearyl Olivate, Sorbitan Olivate, Hamamelis Virginiana Leaf Water, Saccharide Isomerate Hydrogenated Olive Oil, Olea Europaea Fruit Oil, Olea Europaea Oil Unsaponifiables, Madecassoside, Azelamide MEA, Polygonum cuspidatum root extract, Perfluorodecalin, Myristyl alcohol, Tocopheryl Acetate, Allantoin, Arginine, Poloxamer 188, PCA, Polyperfluoromethylisopropyl Ether, Sodium Dextran Sulfate, Sodium Acrylate/ Sodium Acryloyldimethyl Taurate Copolymer, Citric Acid, Sodium Citrate, Potassium Sorbate, Sodium Benzoate, Gluconolactone, Calcium Gluconate, Disodium EDTA, Propanediol, Propylene Glycol, Diazolidinyl Urea, Methylparaben, Propylparaben.Про эффектУ меня кожа комбинированного типа от сухой к нормальной, бывает акне, очень долго проходят постакне, поры расширены. Да я ж идеальный кандидат для использования этого крема!Я честно пользовалась этим кремом 2 недели. Понимаю, что у меня случай сложный, большие пятна от подкожников, но все же. Даже без лечения они по идее должны сильно светлеть за 2 недели, но тут тишина прям мертвая. До, уже с кремом на лице После 2х недель До, уже с кремом на лице После 2х недельЧто касается увлажнения, то мне на жару эффекта хватило, а так это скорее крем для жирной кожи, на суховатую не в жару соло наносить не получится, нужна будет еще какая-нибудь увлажняющая сыворотка.Про этичностьК сожалению, марка не этична, хотя подвижки есть.ВыводМне не понравилось, к сожалению с моими большими пятнами от подкожников крем совсем не помог. Как крем на лето для проблемной кожи ок, пойдет, но какие-либо проблемы он все же не решает. Ну, хотя бы и хуже не делает.____________________________________Мои отзывы на другие кремы при прыщах:  ',
#  'Крем Ла-Кри для чувствительной кожи вызывает сильную аллергию сразу после нанесения.Информация о том, что крем уменьшает зуд и раздражение, снимает покраснение кожи, а также бережно ухаживает за кожей - ЛОЖЬ.Крайне не рекомендую использовать крем Ла-Кри для чувствительной кожи так как этот крем вызывает сильную аллергию сразу после нанесения.Вызывает аллергию!  ',
#  'Всем здравствуйте! 👥\xa0Сегодня я хочу Вам рассказать о креме для лица "Лецитин и Витамин С" от Green planet.\xa0 Крем для лица Green planet "Лецитин и Витамин С"\xa0Место покупки: WildberriesЦена: 208 рублейОбъем: 50 мл\xa0| ОТ ПРОИЗВОДИТЕЛЯ |\xa0Легкий универсальный крем с лецитином и витамином С подходит для любого типа кожи. Лецитин восстанавливает естественный липидный слой эпидермиса, смягчает и устраняет шелушения и дискомфорт, а маслорастворимая стабильная форма витамина С и витамин Е действуют как синергисты-антиоксиданты, защищают клетки от окислительного стресса и воздействия УФ-лучей. Крем идеален в качестве увлажняющей базы под макияж. Способ применения: равномерно нанести на очищенную кожу лица и шеи утром и/или вечером. Подходит для ежедневного использования.\xa0| СПОСОБ ПРИМЕНЕНИЯ |\xa0Равномерно нанести на очищенную кожу лица и шеи утром и/или вечером.\xa0| СОСТАВ |\xa0A q u a ( Wa t e r ) , Glycerin, Caprylic/Capric Triglycerides, Octyl Stearate, Sodium Acrylates Copolymer, Lecithin, Cyclopentasiloxane, Ascorbyl Tetraisopalmitate, Dimethicone, Dimethicone/Vinyl Dimethicone Crosspolymer, Tocopheryl Acetate, Ethylhexylglycerin, Phenoxyethanol, Citric Acid.\xa0| УПАКОВКА |\xa0Крем упакован в достаточно удобный флакон с дозатором. Он имеет чуть сплющенную цилиндрическую форму, которая не занимает много места и легко помещается даже в самую маленькую сумочку. С обеих сторон присутствую этикетки ярко-голубого оттенка, на которых напечатана вся информация о продукте.\xa0 Крем для лица Green planet "Лецитин и Витамин С"\xa0Флакон сделан из чуть мутноватого, но все же прозрачного пластика, благодаря чему легко отслеживать расход и остаток крема внутри.\xa0 Крем для лица Green planet "Лецитин и Витамин С"\xa0Дата изготовления напечатана на дне. В закрытом виде флакон может храниться 3 года, а после начала использования его необходимо "добить" за полгода. Мне при регулярном использовании 2 раза в день его хватило на 1,5 месяца.\xa0 Крем для лица Green planet "Лецитин и Витамин С"\xa0Дозатор дополнительно защищен при помощи плотной и толстой пластиковой крышки.\xa0 Крем для лица Green planet "Лецитин и Витамин С"\xa0Он помпового типа, сделан из белого пластика. Работает исправно, при первых нажатиях несколько раз работал вхолостую. На основании имеется специальная выпуклая поверхность, не позволяющая пальцу соскальзывать при нажатии. Крем для лица Green planet "Лецитин и Витамин С"\xa0Отверстие внутри изначально кажется каким-то подозрительно маленьким, но по факту во время использования понимаешь, что его размер абсолютно не имеет значения, так как крем подается очень легко. Порция за раз приличная, но не огромная, лично для меня на все лицо 1-го нажатия оказалось маловато, а 2-х уже было много, поэтому я использовала 1,5.\xa0 Крем для лица Green planet "Лецитин и Витамин С"\xa0| О ПРОДУКТЕ |\xa0По структуре на первый взгляд крем кажется плотным и густым, но это не так. Отдушка у него не сказать, что очень уж приятная, но более менее приемлемая, такая косметическо-кислая.\xa0 Крем для лица Green planet "Лецитин и Витамин С"\xa0Текстура однородная, без каких-либо частичек. Тактильно она довольно-таки силиконистая, но при этом легко и быстро распределяется по коже.\xa0 Крем для лица Green planet "Лецитин и Витамин С"\xa0Поначалу во время нанесения на коже можно почувствовать небольшую липкость, которая проходит, как только крем окончательно впитается в кожу, а происходит это быстро, нужно подождать всего лишь несколько секунд.\xa0 Крем для лица Green planet "Лецитин и Витамин С"\xa0| ПРИМЕНЕНИЕ |\xa0Моя кожа на лице: жирная, но часто обезвоженная, с расширенными порами, постакне и периодически появляющимися высыпаниями.\xa0 Крем для лица Green planet "Лецитин и Витамин С"\xa0С маркой Green planet ранее, по-моему, я знакома не была. Случайно обратила на них внимания на Wildberries, потому что у крема был очень хороший рейтинг и много положительных отзывов. Также сыграла свою роль и цена, ведь за 50 мл крема просили всего ...
#  'Здравствуйте,\xa0Осенью-зимой 2020-2021 я наткнулась на баннерную рекламу бренда и решила попробовать продукцию, тем более, что тогда цены еще, оказывается, были более чем приемлемые, да еще и со скидками. Я заказала умывашки, крем для лица, маска и сыворотка были в составе увлажняющего набора. Сегодня подробно остановлюсь на креме для лица. \xa0ОБЩАЯ ИНФОРМАЦИЯ\xa0наименование - Интенсивно увлажняющий S.O.S крем Vinosource-Hydraобъем - 50 млцена - 2850 рубсрок годности после вскрытия - 6 меспроизводство - Франция\xa0УПАКОВКА\xa0Я покупала крем в составе набора для увлажнения кожи, кроме самого крема там еще были сыворотка и маска. Плюс положили кучу подарочков-пробников. Соответственно, отдельной коробочки у крема не было.Крем залит в тяжелую стеклянную матовую банку-шайбу. Крышка винтовая, между ней и банкой есть прослойка от попадания воздуха. Набирать крем пальцами, шпателя в комплекте не было. На банке минимум информации. \xa0СОСТАВ\xa0aqua/water/eau, glycerin*, squalane*, ethylhexyl cocoate*, ethylhexyl palmitate*, cetearyl alcohol*, vitis vinifera (grape) fruit water*, borago officinalis seed oil*, potassium cetyl phosphate, coco-caprylate/caprate*, cetearyl wheat straw glycosides*, caprylic/capric triglyceride*, palmitoyl grape seed extract*, vitis vinifera (grape) juice*, crithmum maritimum extract*, sodium carboxymethyl beta-glucan, sodium hyaluronate, oleyl alcohol*, cetearyl glucoside*, hydrogenated olive oil stearyl esters*, parfum (fragrance), tocopheryl acetate*, carbomer, caprylyl glycol, hydrogenated vegetable oil*, helianthus annuus (sunflower) seed oil*, citric acid*, sodium hydroxide, tocopherol*, acrylates/c10-30 alkyl acrylate crosspolymer, potassium sorbate, sodium benzoate (235/001)Состав хорош, кроме того, на оф сайте бренда можно найти информацию о том, что еще вредного не содержится в креме, я здесь все это перечислять не буду, лишь упомяну, что в составе нет средств, раздражающих кожу, наносящих вред планете коже.\xa0ТЕКТСТУРА И ОТДУШКА\xa0По текстуре крем кажется легким, но при нанесении на кожу чувство легкости исчезает, крем ложится тяжелой силиконовой пленкой. Отдушка цветочно-маслянистая.\xa0МОИ ВПЕЧАТЛЕНИЯ И РЕЗУЛЬТАТЫ\xa0Моя кожа:31 годкомбинированная, жирная т-зона, остальное ближе к нормальному типулетом становится более жирной, зимой чуть сушеесть некоторые возрастные изменениябывают высыпаниякожа пористая, особенно в области т-зоныМои ожидания:увлажнение, так как крем в первую очередь увлажняющийбез жирной липкой пленкихорошее взаимодействие с декоративной косметикойкрем не должен вызывать проблем с кожей - высыпаний, забитых пор и т.д.Обещания производителя:Интенсивно Увлажняющий S.O.S. Крем Vinosource-Hydra придет на помощь самой чувствительной сухой коже. Он интенсивно увлажняет кожу, устраняет покраснения, чувство стянутости и повреждения, вызванные внешними агрессивными факторами. Кожа становится более упругой, и чувство комфорта не покидает вас на протяжении всего дня.В результате:увлажнение. Мне не очень понравился увлажняющий эффект. Конечно, он присутствует, так же как и смягчение кожи, но нет эффекта именно мощного увлажнения, как иногда бывает с некоторыми кремами или сыворотками. Если оценивать, то увлажнение на троечкулипкая жирная пленка. Надо признать, давно я не встречала подобного эффекта. Сейчас в основном пользуюсь Кларанс и Филорга, и уже забыла, что такая проблема вообще существует. Но у Кадали пленка присутствует. Есть какой-то эффект маски, который я уже второй раз встречаю именно в натуральной косметике. В первый раз встретила его в обзорном креме какого-то нашего бренда, но тогда подумала, что может, формула не совсем доработана, к тому же, не самый известный и зарекомендовавший себя производитель. Но уже второй раз и именно в натуральной косметике - вряд ли это совпадение. Может, вместо привычных силиконов здесь какой-то подобный ингредиент? Остается только гадать, но эффект маски очень сильно портит впечатление от кремавпитываемость. Крем впитывается полностью ...
#  'Классика - начиталась отзывов, что Bioderma меньше всего ощущается на коже и решилась на этот крем. Чудесно, что заказала миниатюру! Потому что мне он не подошел (когда есть с чем сравнить..) А теперь подробнее. \xa0 Моя кожа типично сложная. Если конкретнее, то чувствительная (очень долго не пользовалась никакими средствами для лица вообще, потому что эффекта ноль, а ощущение пленки/отеки - от всего), ближе к сухой на щеках, с куперозом на крыльях носа, и Т-зоной, которая легко покрывается блеском. 28 лет.\xa0Собственно, для носа и всегда румяных щек этот крем и хотелось опробовать, потому что линия AR для этого предназначена. Конечно, против сосудистых звездочек поможет только лазер, но вот осветлить покраснения - такую влажную надежду я ещё лелею.\xa0Состав крема: WATER/EAU, MINERAL OIL (PARAFFINUM LIQUIDUM), GLYCERIN, TRIDECYL TRIMELLITATE, GLYCOL PALMITATE, CAPRYLIC/CAPRIC TRIGLYCERIDE, CANOLA OIL, TRICETEARETH- 4 PHOSPHATE, FRUCTOOLIGOSACCHARIDES, MANNITOL, XYLITOL, RHAMNOSE, LAMINARIA OCHROLEUCA EXTRACT, GLYCYRRHETINIC ACID, GLYCINE SOJA (SOYBEAN) GERM EXTRACT, ALLANTOIN, GINKGO BILOBA LEAF EXTRACT, CAMELLIA SINENSIS LEAF EXTRACT, PROPYLENE GLYCOL, PENTYLENE GLYCOL, CAPRYLYL GLYCOL, GLYCOL STEARATE, PEG-2 STEARATE, ACRYLATES/ C10-30 ALKYL ACRYLATE CROSSPOLYMER, 1,2- HEXANEDIOL, CITRIC ACID, XANTHAN GUM, DISODIUM EDTA, SODIUM HYDROXIDE.Скрыть цитату\xa0Ну и собственно минеральное масло на втором месте, как я полагаю, и вызвало весь мой дискомфорт - а именно, вполне конкретное "душно" ощущение на коже. Нет, это не совсем пленка, но потеет всё под кремом просто мгновенно. А уж по глупости нанеся крем на лоб и подбородок я получила вполне конкретно забитые поры и прыщики, ну и конечно аццкую жирность к концу дня.Никакого осветления, но и воспалений на целевой поверхности (нос, щеки) не было.Отсутствие запаха считаю плюсом, жирненькую текстуру желтого крема с удобным процессом распределения тоже отношу к плюсам. А ещё он мне показался очень экономичным, потому что мой пробник, пользуемый примерно через день, был со мной не меньше трех месяцев.  ',
#  'Всем доброго времени суток и хорошего настроения!\xa0Итак, сегодня мой отзыв будет посвящен крему для лица "Антистресс" Шиповник и солодка от фирмы-производителя Green Mama. Данный крем брала впервые, так как нужен был именно такой, где в составе присутствует шиповник. Подобным кремом с шиповником когда-то пользовалась (не этого производителя) и была очень довольна. Решила взять от Green Mama и опробовать его в условиях лета и теплого периода года. И для защиты кожи от УФ, а также неблагоприятной окружающей среды. Крем для лица GREEN MAMA "Антистресс" Шиповник и солодкаКожа в состоянии стресса выглядит уставшей, безжизненной, на ней заметны мелкие морщинки. Ухудшается её кровообращение, нарушается тканевое дыхание. Экстракт шиповника, содержащий витамин С, обладает антистрессовыми свойствами, а экстракты облепихи, солодки, чабреца и малины ─ это неисчерпаемый кладезь регенерирующих и антиоксидантных свойств. Кунжутное и миндальное масла содержат великолепный набор витаминов А, Е и В5. Китайский лимонник активизирует работу клеток, помогает преодолевать усталость. Крем содержит УФ-фильтры, защищающие от вредного воздействия солнечных лучей, отдаляя увядание кожи.Моя кожа: 30+, смешанного типа, чувствительна к холоду/перепаду температур и стрессам. Я аллергик со стажем (в том числе и на декоративную, и ухаживающую косметику). Периодически нужно питание, увлажнение без аллергической реакции, в дополнение - использование как средство-основу под макияж.Стоимость на момент покупки: 160 руб. (со скидкой + распродажа), без скидок/акций/распродаж цена 385 руб. за 1 упаковку объемом в 50 мл. Как-то дороговато, если брать по полной стоимости. Крем для лица GREEN MAMA "Антистресс" Шиповник и солодкаМесто покупки: официальный интернет-магазин фирмы-производителя. Есть бесплатная доставка (при покупках от 1500 руб.). Выбрала доставку в пункт выдачи (вместе с другими средствами). Все пришло целое и хорошо упакованное, ничего не разлилось и не потрескалось.Кстати, хотелось бы заострить внимание на том, что крышки упаковок очень хрупкие и луче тюбики не ронять - крышка трескается сразу и тогда средство может быстро испортиться.Упаковка: обычный пластиковый светлый тюбик с изображением растений, на лицевой стороне само название крема, имя фирмы-производителя. На упаковке есть дата производства, сроки годности (после вскрытия упаковки - 6 месяцев), состав, способ использования и информация от производителя.\xa0Наносить тонким равномерным слоем лёгкими похлопывающими движениями.Страна-производитель: Россия.Бренд: Green Mama.\xa0Данный крем относится к категории дневных кремов.Серия: Формула тайги. Крем для лица GREEN MAMA "Антистресс" Шиповник и солодкаКонсистенция: светлая, с не очень приятным запахом ингредиентов (крем пришел свежий!), но терпимо и после нанесения на кожу выветривается. Консистенция показалась какой-то жидковатой для крема. То ли его разбавили чем-то, то ли сам по себе отстаивается. Не ясно. Но как-то не очень приятно.Состав: более менее натуральный.Вода деминерализованная, кунжутное масло*, глицерилстеарат*, стеариновая кислота*, миндальное масло*, октилметоксициннамат, сок алоэ вера*, Д-пантенол, экстракты* лимонника китайского, шиповника, солодки, облепихи, малины, каприк/каприлик триглицерид*, цетеариловый спирт, витамин Е (токоферилацетат), витамин А (ретинилпальмитат), эфирное масло розового дерева*, аллантоин*, бутилметоксидибензоилметан, карбомер, парабены, триэтаноламин.* ─ продукт растительного происхождения. Крем для лица GREEN MAMA "Антистресс" Шиповник и солодкаПлюсы:Хороший объём (удобный тюбик, можно брать с собой в косметичку-сумку, много места не займет).Хорошо впитывается и даже немного матирует.Хорошо питает и увлажняет кожу (у меня кожа смешанного типа), немного выравнивает тон.Улучшает цвет лица.Состав - более менее натуральный и данный крем не вызвал аллергии или неприятных ощущений.Подошел в качестве основы под макияж.Подойдет и для холодного времени года *но не для суровой зимы, для периода сильных хол ...
#  '╔Введение╗Зарекалась конечно, и не раз, не покупать больше микситовский косметос. Но видимо к старости память несколько ослабела и время от времени продолжаю совершать набеги на отделы этого бренда. Или это надежда найти хоть что-то нормальное у них не даёт мне покоя, не знаю. Люблю я гликолевую кислоту в уходе, и решила прикупить их ночной крем с ней, хоть и привыкла к большему проценту этого ингредиента. Пометки о pH не было. Повелась на хорошие отзывы, коих предостаточно.Могу сказать точно, что это неудачная покупка, возможно даже самая неудачная за весь этот год. В прошлом году пальму первенства брала хваленая эссенция от Пайо с огрызками василька в бутылке, о которой мне даже лень написать. Крем для лица MIXIT AHA! Revolution Night Cream glycolic 5% Ночной C гликолевой кислотой\xa0╔Описание и характеристики╗Производство - РоссияОбъем 50мл.Срок годности после вскрытия - 6 месяцевЭтот ночной крем представлен в линейке АНА Революшн от Миксит, ее отличительные черты - наличие гликолевой кислоты в составе. Кислот в ней содержится мало, видимо чтобы подразнить школоту, и при этом не спалить им всю кожу.Купить их заказать средство можно везде где представлен Миксит, продукт не дефицитный. Ценник варьируется от 500 до 800 рублей.Продается в картонной коробке, банка из под крема - типичный пластик. Была заглушка под крышкой, но я ее выкинула. Была ли защита от вскрытия не помню. Содержимое с характерным кислым запахом, очень плотное и густое, впитывается плохо оставляет ощущение плёнки на лице. Расход маленький.       Крем для лица MIXIT AHA! Revolution Night Cream glycolic 5% Ночной C гликолевой кислотойОписание в интернете вызывает недоумение, прямо-таки средство от всего и для всего:✅МИКСИТ Ночной питательный крем для лица, зоны шеи и декольте с гликолевой кислотой избавит кожу от следов постакне, пигментных пятен и пигментаций. Косметическое средство ухода за собой AHA! Revolution face cream способствует сужению пор и выравниванию тона кожи, дарит интенсивное увлажнение и питание. Увлажняющий крем с питательным эффектом имеет накопительный омолаживающий эффект, помогает против глубоких и мимических морщин.Профессиональная натуральная уходовая косметика женская mixit в виде питательного крема подходит для жирной, проблемной, сухой, комбинированной, чувствительной, обезвоженной, возрастной, молодой, зрелой, нормальной, увядающей и раздраженной кожи. Легкий антивозрастной крем анти-акне содержит глицерин, органические и гипоаллергенные компоненты.Масло ши интенсивно питает, ускоряет омоложение и восстановление клеток, устраняет покраснения и раздражения.Гель алоэ вера имеет успокаивающий и восстанавливающий эффект, стимулирует заживление кожного покрова.Пантенол снимает воспаления, оказывает противовоспалительное действие.Экстракт готу колы возвращает коже упругость и эластичность.Гликолевая кислота и аллантоин отшелушивают мертвые клетки, предотвращают появление высыпаний, черных точек на носу и подбородке, жирного блеска.Результат: лицо без проблем, идеальная кожа с ровным тоном. Питательный крем с гликолевой кислотой обеспечивает красоту, сияние и здоровье, способствует моделированию контура овала лица, снимает чувство усталости.Наносите средство вечером или на ночь на сухое и чистое лицо после очищения, избегая области вокруг глаз и век. Применяйте 2-3 раза в неделю.✅Гликолевая кислота 5% – нормализует процесс обновления эпидермиса, сужает поры, выравнивает микрорельеф кожи, устраняет тусклость и шероховатость, сглаживает следы пост-акне. Масло карите (ши) богато каристеролами и жирными кислотами, защищающими кожу от обезвоживания и высыхания.Наносить AHA! Revolution Night Cream вечером на чистое, сухое лицо после умывания. Рекомендуется применять 2-3 раза в неделю. Для максимального эффекта комбинируй с другими средствами из коллекции AHA! Revolution.Состав кое-где указан некорректно, актуальный тут:Aqua, Aloe Barbadensis Leaf Gel, Butyrospermum Parkii Butter, Glycolic Acid, Cetearyl Alcohol, Glycerin, Glyceryl Stearate, P ...
#  "Всем здрасте))В начале мая я отправилась в магазин Подружка, чтобы пополнить свои запасы уходовой косметики. Поскольку в мае у нас уже было очень жарко, то моя кожа очень сильно страдала от повышенной жирности, матирующим кремом я хотела решить этот вопрос.На самом деле вопрос был не в повышенной жирности кожи, а в том, что нужно было удалить источник стресса, который и способствовал тому, что кожа сходила с ума и обливалась жиром.Но мы сейчас ведём речь о креме, который по заявлению производителя является матирующим, и призван бороться с повышенной жирностью кожи.Крем для лица A'PIEU Cicative Zinc Cream с цинком a'pieu крем с цинком🔴 Общая информация:производитель Южная Кореяобъем 50 млактуальная цена 1090 рублей (740 рублей по акции при покупке)место покупки Подружкагде еще купить вайлдберрис, озон, яндекс маркет, летуаль\xa0🔴 Мои параметры оценки:быстро впитываетсяматирует кожунемного сглаживает рельефне камедогенныйне ощущается пленкой на лице🔴 Информация от производителя:Успокаивающий крем эффективно ухаживает за чувствительной кожей лица благодаря входящему в его состав цинку, который прекрасно регулирует работу сальных желез, очищает поры и придает здоровый вид коже, активно способствует разглаживанию мимических морщин, восстанавливает эластичность и упругость кожи. Аллантоин, увеличивая содержание воды в клетках кожи, обладает мощным увлажняющим эффектом, отлично защищает от вредных воздействий окружающей среды,способствует клеточной регенерации и ускоренному заживлению. Минеральная вода питает кожу, насыщает ее необходимыми микроэлементами, укрепляет и тонизирует.🔴 Упаковка:Внешне тюбик крема чем-то напоминает аптечную косметику a'pieu кремИзначально он был запаян в слюду, она имеет перфорацию, чтобы было легко и удобно открыть Крем A'PIEU ZincСзади на слюде прикреплена наклейка русификатор Крем для лица A'PIEU Cicative Zinc Cream с цинкомПомимо этого крем имеет защитную фольгу на горлышке. Крем для лица A'PIEU Cicative Zinc Cream с цинкомНа сварочном шве указан срок годности a'pieu крем для лицаКак и на всей косметике A’pieu на самом тюбике информация написана только на языке производителя a'pieu крем🔴 Запах и консистенция:Честно сказать, уже на этом этапе я заподозрила, что с этим кремом что-то не так a'pieu кремОн был слишком плотным, слишком белым, но где-то в глубине души мне казалось, что возможно при распределении по коже он покажет хороший результат a'pieu крем для лица отзывыТем не менее чуда не случилось. Я больше чем уверена, что описанию у крема не совпадает с его содержимым. Уже позже я начала штудировать все сайты, на которых он представлен в продаже и нашла один сайт, на котором абсолютно иное описание, которое совпадает с тем, что находится внутри тюбика. Это вообще похоже по текстуре на крем с спф защитой. a'pieu крем для лица отзывыДаже спустя 5 минут остается лежать плёнкой на коже a'pieu крем для лицаПолное впитывание происходит только минут через семь – восемь. Однако, нужно посмотреть, как крем поведёт себя на лице a'pieu крем для лица🔴 Способ применения:После умывания протрите кожу тоником. Нанесите небольшое количество средства на щёки, лоб,подбородок и нос. Легкими похлопывающими движениями распределите крем по всей области лица, помассируйте кожу до полного впитывания. Только для наружного применения. Избегайте контакта с глазами. Хранить в недоступных для детей местах. В случае появления раздражения, немедленно прекратить использование. Хранить при температуре от +5°С до +25°С.🔴 Исходные данные:У меня жирный тип кожи, поры расширены, на этом фото я после механической чистки лица. a'pieu крем🔴 Ощущения:Это последнее использование крема, снятое для этого обзора. Я пробовала его в разные периоды, с разными тонерами, результат один.Я нанесла на лицо увлажняющий тонер и после этого, пока кожа от тонера ещё не просохла, я наношу сверху крем. Использую на лицо порцию меньше, чем горошина a'pieu крем с цинкомЕсли честно, то ощущение ужасное, такое чувство, будто лицо намазано какой-то шпаклёвкой.  ...
#  'Всем привет! Кремом от чистой линии пользовалась долго, потому что он дешевый и не знала какой выбрать в следующий раз.  У меня после него не было таких вещей как гладкость, свежесть, сияние , просто увлажнял. Но и прыщи не появлялись. Но кстати запах у него удачный: лёгкий и ненавязчивый  У него жидкая консистенция и он выливается из тубы, если повернуть вертикально. Я его покупала несколько раз и как мне показалась упаковка становилась все ЛУЧШЕ, а качество ХУЖЕ. То есть как-будто все больше разбавленный водой. Кожа, может быть, какое-то время бывает матовой, но потом жирнитсяВообще вся продукция чистой линии кажется мне сомнительной. Крем я не советую, можно найти немного подороже, но намного лучше, сейчас пользуюсь другим.В отзывах все пишут типа чего вы хотели за 70 рублей, но я его в последний раз покупала за 160.  ',
# ...
#  'Добрый день. Сегодня я хочу рассказать вам про гиалуроновый филлер Librederm "Преображающий крем Blur 3D". Покупала я его в самой обычной аптеке. Стоимость была около 800 рублей. Но можно купить на маркетплейсах, Wildberries, Ozon. ПРО КРЕМВнутри картонной коробки вы найдете небольшой тюбик крема объемом 15мл. Оформлен в серо-синих тонах.  Крышка в стиле открутил/закрутил серебристого цвета. Благодаря небольшому отверстию дозируется удобно. Можно выдавить столько, сколько необходимо, не переборщив.  С обратной стороны тюбика есть вся необходимая информация ( общая информация, состав, производитель, сроки годности). Преображающий крем-BLUR - уникальное средство, сочетающее в себе свойства праймера и увлажняющего крема. С одной стороны, благодаря 3D гиалуроновой кислоте с молекулами разной массы он работает на глубокое увлажнение кожи и способствует уменьшению морщин, с другой - благодаря светоотражающим частицам преображает кожу лица. Теплые цветовые пигменты и светоотражающие частицы сглаживают неровности тона кожи, делая ее ровной и безупречной. Становятся незаметными поры, мелкие морщинки и носогубные складки. Легкий персиковый тон придает коже здоровый оттенок. Кожа глубоко увлажнена, выглядит ровной и безупречной. Крем обладает легкой текстурой, не оставляет чувства липкости и следов.Итак, что же представляет из себя сам крем? Он имеет довольно густую, но легкую консистенцию приятного розового цвета. При нанесении на лицо и соприкосновении с кожей буквально скользит и отлично распределяется по ней. Преображающий крем имеет практически не уловимый аромат. Легкие нотки крема ощущаются только если специально принюхиваться.  Знаете, по ощущениям он как бы проникает в кожу моментально. Он как бы заполняет ее. Постаралась показать на фото процесс распределения крема по коже.  Состав... Это отдельная тема. Если вы за натуральные компоненты - то лучше пройти мимо. 4 компонента из состава экоголик оценил на 2 из 5.Ciclopentasiloxane, Caprylyl Methicone, C30-45 Alkyl Cetearyl Dimethicone Crosspolymer, Polymethylsilsesquioxane, Boron Nitride, CI 77891, Mica, Tin Oxide, Sodium Hyaluronate, Ricinus Communis Seed Oil, Hydrogenated Castor Oil, Synthetic Fluorphlogopite, CI 77491Срок годности - 2 года.После вскрытия- 6 месяцев.\xa0МОЙ ОПЫТ ИСПОЛЬЗОВАНИЯНемного о себе. У меня сухая кожа. Но, но проблемная. Как говорится морщины не за горами, а еще прыщи не ушли. Комбо!В поисках чего-то интересного для своей кожи я и познакомилась с данным кремом.Использовать крем-BLUR рекомендуется после нанесения средства дневного ухода. Распределите небольшое количество средства по всей коже лица или только на Т-зоне, области расширенных пор и морщинок легкими похлопывающими движениями кончиков пальцев, не растирая.Я наношу его тонким слоем на чистую сухую кожу лица. Сейчас покажу результат.ДО: ПОСЛЕ: Кожа становится как будто матовая. На ощупь просто бомба, такая бархатистая.Тональные крема нанесенные поверх не скатываются и не сбиваются.  \xa0Но к крему у меня остались вопросы. У меня уже было однажды средство с похожими свойствами, это минеральный праймер фирмы E.L.F, который я заказывала с iherb. Но цена его выходила в два раза дешевле. Он так же распределялся и выравнивал кожу. Но, данный крем должен обладать еще и увлажняющими свойствами, но увы их нет. Да и сам производитель рекомендует наносить крем после дневного ухода. Тогда смысл переплачивать? Проще купить только праймер если результат такой же.  Еще все же не рекомендую данный крем для ежедневного применения, он забивает поры прилично. Я использую его только "на выход", или когда макияж должен быть в идеале до вечера.Подведем итоги. Помимо плюсов данный крем имеет и множество минусов о которых я рассказала в отзыве. Покупать или нет - решать вам. Я все же крем рекомендую, но только 3 звезды.   ',
#  ' Впервые слышу про такой бренд. Рекламу не видела, на полках магазина внимание не обращала. По упаковке мне не понятно к какому сегменту принадлежит, по стоимости тоже.Однако он первый на что я хочу написать из всего набора.Цена:Не могу сказать и высчитать, так как попался пробник 7,5 мл в бьюти боксе новогоднем. Покупала себе на др. Но переезды, разъезды и прочее, позволили мне вскрыть его только в июне 😆 так что я не смотрю на сроки годности, но учитываю что всякое может быть))Где купить:иль де Боте полная стоимость 10 т. р. с копейками, по карте вип 7 с чём-то. За банку в 50 мл.Сефора по карте лояльности 7 672. Полная цена 10 230 р.proficosmetics 10235 р. На этом сайте примечательно что, указана цена за 1 мл. 204.70 в данном случае и с данной ценой выходит стоимость.Cosmofun 11633 р.На озоне продаёт РИА Гош и в нём дешевле, чем в самом рив Гош.Вб 7110 р.На сайте самого бренда указано что базовая цена: 8802 руб. Так что что на вб я не знаю. Вариантов много.В общем, как оказалось популярный бренд, который много где продаётся. Это просто я не в теме. Но желающие легко смогут найти его во многих онлайн маркетах и интернет магазинах.Состав:Вот это заманали меня. Пол вечера лазила по сайтам и и макала полный состав, но в большинстве магазинов в графе состав пишут "пептиды, масло ши" +/-А на самом деле состав намного объемнее и не такой приятный и натуральный как пытаются показать.В итоге психанула и в ручную пришлось перепечатывать. Не благодарите water (aqua), butyrospermum parkii (shea) butter, polymethyl methacrylate, dimeticone, methylsilanol hydroxyroline aspartate, sodium ACRYLATES copolymer, do methylsilanol hyaluronate, phospholipids, phenoxyethanol, ethylhexyglycerin, propanediol, ornithine, glycolipids, peg -40, olea europaea (olive) fruit oil, c10-18 triglycerides, centella asiatica extract, caprylyl glycol, chlorphenesin, tocopherol, helianthus annuus (sunflower) seed oil, xanthangum, disodium edta, sodium hyaluronate, hydrolysed hyaluronic acid, silanediol salicylate, tromethamine, methylpropanediol, castor seed oil, anthem is nobilis flower oil, lavender flower extract, hydrolysed wheat protein, palmitoyl decapeptide-21, decapeptide-22, oligopeptide-78, zinc palmitoyl nonapeptide-14, trehalose, betaine, lecithin, silica, silanetriol, hyaluronic acid, palmitoyl oligopeptide, glycolic acid, lactic acid, polyvinyl alcoholМного всего здесь полезного. Много того, что не расшифровывается и не понятно что скрывается за наименованием.Пептиды, масла, экстракты.Но бесполезного и плохого здесь тоже в достатке.От меня, минус за состав. Все диметиконы и прочая химия всегда отталкивают. И вредят коже. Одно лечит, другое калечит. Не люблю такие спорные составы.\xa0   О креме:Прочитала описание к этому крему, и прям всё так ладненько и складненько у них.Результаты клинических испытаний:- Через 15 минут…100% добровольцев отметили видимое разглаживание морщин и кожных линий.- Через неделю … 94% отметили что кожа стала более наполненной и объемной.Лично я не вхожу ни в 100 ни в 94%Есть некий положительный эффект, но разово и то не факт что заслуга крема.На данный момент использован весь тюбик. Хватило на 25 дней ежедневного применения. Если верно помню, то иногда и на ночь наносила.Вижу, что много в рекламу вложили. Но если продукт крутой разве он требует особой рекламы? Сарафанное радио никто не отменял.Ни одно обещание не выполнено по факту, так что отрицательная оценка и не рекомендую к покупке. Ни тонуса, ни свежести, ни сияния.У меня не особо проблемная кожа, комбинированного типа. Летом вроде пока никаких проблем. Может морщинки в уголках глаз, от частого нахождения на солнце, загар, может усталость и сухость на фоне всё того же солнца жаркого. Под прямым не нахожусь, но и кремами с спф не балую кожу.Не знаю какому типу, какой коже и какому сезону рекомендовать этот крем. Может для зимы и для сухой кожи. Так как крем достаточно густой и жирный. А сработать (не сработать) может на любой коже.Крем приятный, текстура вполне удовл ...
#  'Всем здравствуйте!Данный продукт для лица от Клиник я приобрела в duty free за 7 евро и совершенно рада тому, что его всего лишь 30 мл. Есть версии и с большим объемом, но в моем случае свою роль сыграло скорее любопытство, чем потребность и простое желание попробовать что-то новое для лица.   Итак, что у нас по плюсам? Небольшой объем в 30 мл, удобно брать с собой в поездки Лосьон без отдушек, совершенно не пахнет ни чем Можно использовать и днем и в качестве ночного уходаМилое оформление упаковки в стиле КлиникТеперь расскажу почему не возникло желания приобрести больший объем Самый жирный минус для меня - плохо впитывается оставляя пленку на кожеЕсли пользоваться днем, через пару часов лицо люто блестит Не увидела обещанного супер увлажнения Дешево только в дьюти фри, в сетевых магазинах в разы выше ценаПоскольку я больше разочарована, чем рада использованию данного средства, повторно новым пользоваться не буду. Сейчас применяю его только перед сном, а 30 мл заканчиваются довольно быстро и это ещё один неочевидный плюс   ',
#  'Всем привет. Об этом креме я наслышана от многих знакомых и людей в интернете. Решила попробовать сама. Покупала на вайлдберриз, цена со скидкой около 500 рублей. Не самая бюджетная, но и не люкс, конечно. Не могу рассуждать об оригинальности крема, так как пробую его впервые, но упаковка выглядит весьма качественно. Крем поставляется в картонной коробочке нежного голубого оттенка, на нем глазастая девушка с косичками. В стиле Елизавеки.  Есть наклейка типа ориджинал, но я не сверяла.  Сроки годности хорошие, есть штрихкод.  Также есть наклейка с русским языком, где подробно указано действие крема, состав и прочее.  Внутри вас ждут симпатичные глазки, мелочь, а настроение поднимает.  Сам крем в стеклянной б аночке с голубыми капельками, крышка пластиковая, белая с прозрачным колпаком сверху. Выглядит красиво.  На дне баночки номер партии и срок годности до которого используется крем. Сам крем интересной консистенции, гелевый, но как будто тает на коже и превращается в водичку. Никакой лопаточки в комплекте нет, крем доставать придётся пальцами.  Он довольно густой, но хорошо распределяется по коже, как будто тает и становится очень лёгким, почти как легчайшая эмульсия.  При этом кожа, хоть и достаточно увлажненная, но очень липкая. Крем не забивает поры, но и не впитывается полностью в мою кожу, он как будто лежит на ней сверху и всё. Даже спустя пол часа, кожа как будто покрыта липкой плёнкой, волосы липнут, ощущения не супер. Через час я просто умываюсь. Из-за этого использую крем только вечером, утром эта липкость меня убивает. Под макияж тоже не наношу. В общем либо продукт не мой, либо это паль, но увлажнения вроде хватает. О запахе крема скажу, что он ужасен. Как протухший детский крем, очень неприятно.   ',
#  'Привет всем красоткам, забежавшим на огонек) Сегодня расскажу свои впечатления о себорегулирующем кремчике Frudia с зеленым виноградом.  Очень долго к нему присматривалась на iHerb, как долго, что сайт перестал работать у нас в стране)) Но в нашем городе есть девочка, которая занимается корейской косметикой, у нее получилось заказать крем за 1600₽, на ozon и wildberries большая баночка обойдется вам в 2000₽.Крем в красивой стеклянной зеленой баночке, смотрится очень стильно. Я для начала брала попробовать миниатюру крема, мне, что называется, "зашло" и я заказала полноразмерную версию. Миниатюра стоила в районе 300₽.У меня жирная кожа 35+, расширенные (очень) поры, тусклый цвет лица, первые морщины, конечно же, очень быстро лицо превращается в масляный блин, поэтому нужен крем, который хоть немного решит мои проблемы.  Что обещает производитель:Состоящий на 81% из экстракта зеленого винограда, крем-сорбет обеспечивает уход за жирной и комбинированной кожей. Оказывает поросуживающий эффект, выравнивает поверхность кожи, регулирует себовыделение. Пантенол снимает раздражение, масла косточек зеленого винограда и другие масла фруктов питают и смягчают. Крем с натуральным составом подойдет и для чувствительной кожи.Я брала крем на лето, думаю, для зимы он будет слабоват. Но дело в том, что крем не содержит защиту от солнца. Это, конечно, существенный минус. Крем очень приятный, у него удивительная матовая текстура, попробовала заснять, фотография не передает, конечно, всей красоты.   Что мне не нравится - это сам формат баночки, я не люблю такие. Все-так это негигиенично каждый раз пальцем лазить в банку, лопатки под рукой вечно нет, да и не до лопатки обычно, а постоянный контакт крема с руками мало хорошего в себе несет. Поэтому я все-таки отдаю предпочтение кремам с дозаторами. Хотя на вид банка красивая, конечно.  Состав:Vitis Vinifera (Grape) Fruit Extract(81%), Methylpropanediol, Glycerin, 1,2-Hexanediol, PEG/PPG-17/6 Copolymer, Water, Hydroxyethyl Urea, Sodium Carbomer, Betaine, Dimethicone, Panthenol, Octyldodeceth-16, PEG-60 Hydrogenated Castor Oil, Ethylhexylglycerin, Polyquaternium-51, Coco-Caprylate/Caprate, Prunus Armeniaca (Apricot) Kernel Oil, Vitis Vinifera (Grape) Seed Oil, Citrus Paradisi (Grapefruit) Seed Oil, Mangifera Indica (Mango) Seed Oil, Punica Granatum Seed Oil, Solanum Lycopersicum (Tomato) Seed Oil, Tocopherol, Disodium EDTA, Phenoxyethanol, CI 19140, CI 15985, CI 42090, FragranceНеприятный момент - силиконы в составе крема. Все-таки, это вредные штуки и если Frudia позиционирует этот крем как натуральный, состоящий на 81% из экстракта зеленого винограда, то оставшиеся 19% тоже хотелось бы видеть натуральными, а не силиконы! Запах у кремчика очень приятный, легкий, ненавязчивый, немного виноградом отдает. Консистенция густая и сам крем матовый.   Впитывается очень быстро, никаких липких следов не оставляет. Про эффект: я полностью использовала миниатюру и бóльшую часть полноразмерной версии, что могу сказать - каких-то координальных преображений с кожей я, честно, не заметила. После нанесения кожа матовая, гладкая, но этот прекрасный эффект недолговечен и буквально уже через несколько часов ты снова светишься (но не от счастья, а он жирного блеска на щеках и на лбу), накопительного эффекта я не заметила, лучше кожа не стала. То есть эффект есть, но буквально первые пару часов после нанесения, потом карета снова превращается в тыкву, к сожалению. Большой плюс - крем не вызывает аллергии и не забивает поры.Возможно, он подойдет для более молодой кожи от 20 до 30 лет, в целом крем приятный, но глобальных изменений не произошло, поэтому еще раз я его вряд ли куплю. Я его советую, но молодым девушкам, у которых не ярко выражены проблемы с кожей.  ',
#  'Всем привет!Этот крем решила попробовать, поскольку обожаю корейские крема с травами. Баночка крема большая, рассчитан на утро и вечер, есть защитная наклейка.  Как заявляет производитель:Fraijour Крем для лица успокаивающий - Original Wormwood Calming Watery Cream содержит целый комплекс травяных экстрактов и натуральных масел с приятным легким запахом полыни. Быстро впитывается, не оставляя липкости. Подходит для чувствительной кожи. Основные компоненты: полынь, аргинин и аллантоин. Я искала крем для комбинированной кожи и консультант посоветовала мне этот крем. Крема в банке много-100 мл. Лёгкий запах травок, который быстро улетучивается, текстура гелево-кремовая, хорошая, быстро распределяется и впитывается.   С блеском на коже крем не справляется, воспаления особо мне тоже не уменьшил.После использования крема, я поняла, что он больше подходит не коже с прыщиками и воспалениями, как хотела я, а коже с покраснениями, как, например, после загара или купероза, поскольку именно покраснения такого плана, он убирал хорошо.  ']

# %%
len(negative_reviews)
# Out:
# 40

# %%
with open('negative.txt', 'w', encoding='utf-8') as newf:
    newf.write('\n'.join(negative_reviews))

# %%
with open('positive.txt', 'r', encoding='utf-8-sig')as f:
    positive_reviews = f.readlines()
with open('negative.txt', 'r', encoding='utf-8-sig')as f:
    negative_reviews = f.readlines()

# %% [markdown]
# ## Токенизация, нормализация

# %% [markdown]
# Для начала разобью на тестовую и обучающую выборки:

# %%
pos_train, pos_test = positive_reviews[:30], positive_reviews[30:]
neg_train, neg_test = negative_reviews[:30], negative_reviews[30:]

# %%
from nltk.tokenize import TweetTokenizer, sent_tokenize
from pymorphy2 import MorphAnalyzer
from string import punctuation
import re

# %% [markdown]
# Я решила для токенизации выбрать TweetTokenizer, так как в таких отзывах любят использовать всякие эмодзи и смайлики, а этот токенизатор умеет с ними работать.

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
sw = stopwords.words('russian')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kra$0t04ka\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def normalizer(text):
    text = text.replace('\xa0', ' ')
    text = re.sub(r'[a-zA-Z]+', '', text)
    tknzr = TweetTokenizer()
    morph = MorphAnalyzer()
    tokenized = tknzr.tokenize(text)
    without_sw = [w for w in tokenized if w not in sw]
    clean_text = [w for w in without_sw if w not in punctuation]
    normalized = [morph.parse(w.lower())[0].normal_form for w in clean_text]
    return normalized

# %%
from collections import Counter

# %%
# %%time

positive_words = [w for rev in pos_train for w in normalizer(rev)]
negative_words = [w for rev in neg_train for w in normalizer(rev)]
# Out:
# CPU times: total: 14.9 s
# Wall time: 14.9 s

# %%
positive_vocab = Counter(positive_words)
negative_vocab = Counter(negative_words)
only_neg = set(negative_vocab.keys()) - set(positive_vocab.keys())
only_pos = set(positive_vocab.keys()) - set(negative_vocab.keys())

# %%
only_pos_cnt = Counter({w: c for w, c in positive_vocab.items() if w in only_pos and c > 2})
only_neg_cnt = Counter({w: c for w, c in negative_vocab.items() if w in only_neg and c > 2})

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

# %%
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(' '.join(only_pos_cnt.elements()))
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title('positive')
plt.show()

# %%
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(' '.join(only_neg_cnt.elements()))
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title('negative')
plt.show()

# %% [markdown]
# Честно говоря получилась какая-то ерунда( Большая часть слов, какие-то слишком контекстно зависимые и кажется будто вообще не связаны с тональностью... (возможно стоило удалить часть с составом, которая часто встречается в отзывах)

# %% [markdown]
# ## Предсказания

# %%
import numpy as np

# %% [markdown]
# Попробую самый примитивный способ: слова из позитивного словаря умножать на их частоту и плюсовать, а из негативного вычитать

# %%
only_pos_freq = {w: c / len(positive_vocab) * 100 for w, c in positive_vocab.items() if w in only_pos and c > 1}
only_neg_freq = {w: c / len(negative_vocab) * 100 for w, c in negative_vocab.items() if w in only_neg and c > 1}

# %%
def predict(review):
    normalized = normalizer(review)
    rate = 0
    for w in normalized:
        if only_pos_freq.get(w):
            rate += only_pos_freq[w]
        elif only_neg_freq.get(w):
            rate -= only_neg_freq[w]
    return np.sign(rate)

# %%
def accuracy(pred, true):
    true = np.array(true)
    pred = np.array(pred)
    if pred.shape == true.shape:
        return (true == pred).sum() / true.shape[0]
    else:
        raise ValueError('Both arrays should have the same shape')

# %%
test = []
test.extend([(r, 1) for r in pos_test])
test.extend([(r, -1) for r in neg_test])
random.shuffle(test)
y_test = [r[1] for r in test]
x_test = [r[0] for r in test]

# %% [markdown]
# Вообще при таком способе лучше всего работает, если оставить все слова из положительного и отрицательного словаря:

# %%
only_pos_freq = {w: c / len(positive_vocab) * 100 for w, c in positive_vocab.items() if w in only_pos and c > 3}
only_neg_freq = {w: c / len(negative_vocab) * 100 for w, c in negative_vocab.items() if w in only_neg and c > 3}
y_pred = [predict(p) for p in x_test]
accuracy(y_pred, y_test)
# Out:
# 0.5

# %%
only_pos_freq = {w: c / len(positive_vocab) * 100 for w, c in positive_vocab.items() if w in only_pos and c > 1}
only_neg_freq = {w: c / len(negative_vocab) * 100 for w, c in negative_vocab.items() if w in only_neg and c > 1}
y_pred = [predict(p) for p in x_test]
accuracy(y_pred, y_test)
# Out:
# 0.6

# %%
only_pos_freq = {w: c / len(positive_vocab) * 100 for w, c in positive_vocab.items() if w in only_pos and c > 0}
only_neg_freq = {w: c / len(negative_vocab) * 100 for w, c in negative_vocab.items() if w in only_neg and c > 0}
y_pred = [predict(p) for p in x_test]
accuracy(y_pred, y_test)
# Out:
# 0.7

# %% [markdown]
# ## Возможные улучшения

# %% [markdown]
# Что можно сделать:
# - добавить n-граммы (возможно сочетания не с какими-то глаголами/прилагательными будут лучше отражать тональность)
# - оставить в ключевых словах только прилагательные и глаголы
# - обучить на tf-idf и использовать классификатор
# - как-то из отзыва убрать описательную часть, чтобы осталась только часть с мнением о продукте
# - побольше экстраполировать данные, обучаить положительные на отзывах с оценках 5, а отрицательные на 2-3
# - нормально почистить данные

# %% [markdown]
# ### Оставим в словаре только глаголы и прилагательные

# %%
pos = ['ADJF', 'ADJS', 'COMP', 'VERB', 'INFN', 'ADVB']
def normalizer(text):
    text = text.replace('\xa0', ' ')
    text = re.sub(r'[a-zA-Z]+', '', text)
    tknzr = TweetTokenizer()
    morph = MorphAnalyzer()
    tokenized = tknzr.tokenize(text)
    without_sw = [w for w in tokenized if w not in sw]
    clean_text = [w for w in without_sw if w not in punctuation]
    normalized = [morph.parse(w.lower())[0].normal_form for w in clean_text if morph.parse(w.lower())[0].tag.POS in pos]
    return normalized

# %%
positive_words = [w for rev in pos_train for w in normalizer(rev)]
negative_words = [w for rev in neg_train for w in normalizer(rev)]
positive_vocab = Counter(positive_words)
negative_vocab = Counter(negative_words)
only_neg = set(negative_vocab.keys()) - set(positive_vocab.keys())
only_pos = set(positive_vocab.keys()) - set(negative_vocab.keys())

# %%
only_pos_cnt = Counter({w: c for w, c in positive_vocab.items() if w in only_pos})
only_neg_cnt = Counter({w: c for w, c in negative_vocab.items() if w in only_neg})

# %%
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(' '.join(only_pos_cnt.elements()))
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title('positive')
plt.show()

# %%
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(' '.join(only_neg_cnt.elements()))
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title('negative')
plt.show()

# %%
only_pos_freq = {w: c / len(positive_vocab) * 100 for w, c in positive_vocab.items() if w in only_pos and c > 0}
only_neg_freq = {w: c / len(negative_vocab) * 100 for w, c in negative_vocab.items() if w in only_neg and c > 0}
y_pred = [predict(p) for p in x_test]
accuracy(y_pred, y_test)
# Out:
# 0.6

# %% [markdown]
# К сожалению стало только хуже( Хотя вордклауды выглядят лучше :)

# %% [markdown]
# ### Будем использовать n-граммы

# %%
from nltk import ngrams

# %%
from nltk.tokenize import sent_tokenize

# %%
def normalize_sentences(sent_list):
    normalized_sentences = []
    morph = MorphAnalyzer()
    for sent in sent_list:
        normalized_sentences.append([morph.parse(w.lower())[0].normal_form for w in sent])
    return normalized_sentences

# %%
def get_bigrams(review):
    review = review.replace('\xa0', ' ')
    review = re.sub(r'[a-zA-Z]+', '', review)
    review = re.sub(r'[!"#$%&\'()*+,-.\/:;<=>?@[\\\]\^_`{\|}~]+', '', review)
    tknzr = TweetTokenizer()
    tokenized = tknzr.tokenize_sents(sent_tokenize(review))
    normalized = normalize_sentences(tokenized)
    bigrams = [el for s in normalized for el in ngrams(s, 2)]
    return bigrams

# %%
positive_bigrams = [w for rev in pos_train for w in get_bigrams(rev)]
negative_bigrams = [w for rev in neg_train for w in get_bigrams(rev)]

# %%
positive_bigram_vocab = Counter(positive_bigrams)
negative_bigram_vocab = Counter(negative_bigrams)
only_neg_bigram = set(negative_bigram_vocab.keys()) - set(positive_bigram_vocab.keys())
only_pos_bigram = set(positive_bigram_vocab.keys()) - set(negative_bigram_vocab.keys())

# %%
only_pos_freq = {w: c / len(positive_bigram_vocab) * 100 for w, c in positive_bigram_vocab.items() if w in only_pos_bigram}
only_neg_freq = {w: c / len(negative_bigram_vocab) * 100 for w, c in negative_bigram_vocab.items() if w in only_neg_bigram}

# %%
def predict(review):
    bigrams = get_bigrams(review)
    rate = 0
    for b in bigrams:
        if only_pos_freq.get(b):
            rate += only_pos_freq[b]
        elif only_neg_freq.get(b):
            rate -= only_neg_freq[b]
    return np.sign(rate)

# %%
y_pred = [predict(p) for p in x_test]
accuracy(y_pred, y_test)
# Out:
# 0.6

# %% [markdown]
# К сожалению тоже не помогло( Вообще возможно нужно получше почистить данные, потому что там много склеенных слов и, наверное, это сильно портит биграммы...

# %% [markdown]
# ### tf-idf

# %% [markdown]
# Преобразуем все в датафрейм

# %%
import pandas as pd

# %%
data = pd.DataFrame({'review': positive_reviews, 'label': np.ones((len(positive_reviews),))})
data = data.append(pd.DataFrame({'review': negative_reviews, 'label': np.ones((len(negative_reviews),)) * -1}))
data['processed'] = data['review']
# Out:
# C:\Users\Kra$0t04ka\AppData\Local\Temp\ipykernel_6580\3822802788.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(pd.DataFrame({'review': negative_reviews, 'label': np.ones((len(negative_reviews),)) * -1}))

# %%
def all_preprocessing(review_text):
    review_text = review_text.replace('\xa0', ' ')
    review_text = re.sub(r'[a-zA-Z]+', '', review_text)
    tknzr = TweetTokenizer()
    tokenized = tknzr.tokenize(review_text)
    without_punc = [t for t in tokenized if t not in punctuation]
    morph = MorphAnalyzer()
    normalized = [morph.parse(t.lower())[0].normal_form for t in without_punc]
    return ' '.join(normalized)

# %%
data['processed'] = data['processed'].apply(all_preprocessing)

# %%
data
# Out:
#                                                review  label  \
# 0   Всем привет!Сегодня хочу рассказать о необычно...    1.0
# 1   Всем доброго💚Сегодняшний отзыв станет заключит...    1.0
# 2    Всем привет! Сегодня отзыв на дневной крем дл...    1.0
# 3   Когда до 30 осталось всего не чего, пришло сам...    1.0
# 4    Прошлым летом мне подарили тестовый набор кре...    1.0
# ..                                                ...    ...
# 35   Впервые слышу про такой бренд. Рекламу не вид...   -1.0
# 36  Всем здравствуйте!Данный продукт для лица от К...   -1.0
# 37  Всем привет. Об этом креме я наслышана от мног...   -1.0
# 38  Привет всем красоткам, забежавшим на огонек) С...   -1.0
# 39  Всем привет!Этот крем решила попробовать, поск...   -1.0
#
#                                             processed
# 0   весь привет сегодня хотеть рассказать о необыч...
# 1   весь добрый 💚 сегодняшний отзыв стать заключит...
# 2   весь привет сегодня отзыв на дневный крем для ...
# 3   когда до 30 остаться весь не что прийти самый ...
# 4   прошлое лето я подарить тестовый набор крем с ...
# ..                                                ...
# 35  впервые слышать про такой бренд реклама не вид...
# 36  весь здравствуйте данный продукт для лицо от к...
# 37  весь привет о это крем я наслышан от многий зн...
# 38  привет весь красотка забежать на огонёк сегодн...
# 39  весь привет этот крем решить попробовать поско...
#
# [80 rows x 3 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(
    analyzer="word", 
    stop_words=sw, 
    ngram_range = (1, 2),
)

# %%
tfidf.fit(data['processed'])
# Out:
# TfidfVectorizer(ngram_range=(1, 2),
#                 stop_words=['и', 'в', 'во', 'не', 'что', 'он', 'на', 'я', 'с',
#                             'со', 'как', 'а', 'то', 'все', 'она', 'так', 'его',
#                             'но', 'да', 'ты', 'к', 'у', 'же', 'вы', 'за', 'бы',
#                             'по', 'только', 'ее', 'мне', ...])

# %%
train = data[:30].append(data[40:70])
test = data[30:40].append(data[70:])
# Out:
# C:\Users\Kra$0t04ka\AppData\Local\Temp\ipykernel_6580\2305569404.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train = data[:30].append(data[40:70])
# C:\Users\Kra$0t04ka\AppData\Local\Temp\ipykernel_6580\2305569404.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test = data[30:40].append(data[70:])

# %%
train_features = tfidf.transform(train['processed'])
train_features.shape
# Out:
# (60, 22939)

# %%
test_features = tfidf.transform(test['processed'])
test_features.shape
# Out:
# (20, 22939)

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression(random_state=0)

# %%
clf.fit(train_features, train['label'])
# Out:
# LogisticRegression(random_state=0)

# %%
y_pred = clf.predict(test_features)

# %%
accuracy(y_pred, test['label'])
# Out:
# 0.55

# %% [markdown]
# Тоже не помогло(
